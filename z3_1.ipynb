# %% [markdown]
# Задание 1
#
# Переведите содержимое файла purchase_log.txt в словарь purchases вида:
#  {'1840e0b9d4': 'Продукты', ...}
#
# Пример работы программы при выводе первых двух элементов словаря purchases:
#
# 1840e0b9d4 ‘Продукты‘
#
# 4e4f90fcfb  ‘Электроника‘

# %%
import json

def purchase_txt_in_dict(file_path:str) -> dict:
    res = {}
    with open(file_path, "r", encoding="utf-8") as file:
        next(file)
        for line in file:
            purchase = json.loads(line)
            res[purchase["user_id"]] = purchase["category"]
    return res

# %%
res = purchase_txt_in_dict("C:\Users\user\Documents\Project\M1\Home_work\purchase_log.txt")
print(res)
# Out:
#   Cell In[5], line 1
#     res = purchase_txt_in_dict("C:\Users\user\Documents\Project\M1\Home_work\purchase_log.txt")
#                                ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
