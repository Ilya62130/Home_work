# %% [markdown]
# Задание 2
#
# Напишите код на Python для решения следующей задачи.
# Реализуйте функцию trim_and_repeat(), которая принимает три параметра:
# строку;
# offset — число символов, на которое нужно обрезать строку слева;
# repetitions — сколько раз нужно повторить строку перед возвратом получившейся строки.
# Число символов для среза по умолчанию равно 0, а количество повторений — 1.
# Функция должна возвращать полученную строку.

# %% [markdown]
# критерии оценки
#
# Функция trim_and_repeat() принимает три параметра (строку, offset, repetitions) и возвращает полученную строку

# %% [markdown]
# ### Исправление
#
# Срез `text[offset:]` удаляет символы именно **слева**. В исходном варианте `[:-offset]` удалял символы справа.

# %%
def trim_and_repeat(text: str, offset: int = 0, repetitions: int = 1) -> str:
    """Удаляет offset символов слева и повторяет остаток строки."""
    return text[offset:] * repetitions


print(trim_and_repeat("Проверка", offset=2, repetitions=2))
